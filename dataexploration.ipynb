# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import os
dataset_path = r"../Dataset/PlantVillage-Dataset-master"
print(os.path.exists(dataset_path))
# Out:
# True

# %%
classes= os.listdir(dataset_path)
print("number of classes: ", len(classes))

for c in classes[:10]:
    print(c)
# Out:
# number of classes:  16
# .gitignore
# CITATION.cff
# data_distribution_for_SVM
# generated_for_paper
# generate_data_for_SVM.py
# generate_lmdb.sh
# generate_mapstring.py
# leaf-map.json
# leaf_grouping
# logs

# %%
#exploring the file structure of the dataset
classes = os.listdir(dataset_path)
print(classes)
# Out:
# ['.gitignore', 'CITATION.cff', 'data_distribution_for_SVM', 'generated_for_paper', 'generate_data_for_SVM.py', 'generate_lmdb.sh', 'generate_mapstring.py', 'leaf-map.json', 'leaf_grouping', 'logs', 'plant_village.py', 'raw', 'README.md', 'README_HF.md', 'scripts', 'utils']

# %%
for item in os.listdir(dataset_path):
    full_path = os.path.join(dataset_path, item)
    if os.path.isdir(full_path):
        print(f"{item} is a directory.")
    else:
        print(f"{item} is a file.")
# Out:
# .gitignore is a file.
# CITATION.cff is a file.
# data_distribution_for_SVM is a directory.
# generated_for_paper is a directory.
# generate_data_for_SVM.py is a file.
# generate_lmdb.sh is a file.
# generate_mapstring.py is a file.
# leaf-map.json is a file.
# leaf_grouping is a directory.
# logs is a directory.
# plant_village.py is a file.
# raw is a directory.
# README.md is a file.
# README_HF.md is a file.
# scripts is a directory.
# utils is a directory.

# %%
for i in os.listdir(dataset_path):
    full_path = os.path.join(dataset_path, i)
    if os.path.isdir(full_path):
        print(f"{i} is a directory.")
    else:
        print(f"{i} is a file.")
# Out:
# .gitignore is a file.
# CITATION.cff is a file.
# data_distribution_for_SVM is a directory.
# generated_for_paper is a directory.
# generate_data_for_SVM.py is a file.
# generate_lmdb.sh is a file.
# generate_mapstring.py is a file.
# leaf-map.json is a file.
# leaf_grouping is a directory.
# logs is a directory.
# plant_village.py is a file.
# raw is a directory.
# README.md is a file.
# README_HF.md is a file.
# scripts is a directory.
# utils is a directory.

# %%
dataset_path = r"../Dataset/PlantVillage-Dataset-master/raw"
import os
classes = os.listdir(dataset_path)
print("number of classes: ", len(classes))
for c in classes:
    print(c)
# Out:
# number of classes:  3
# color
# grayscale
# segmented

# %%
dataset_path = r"../Dataset/PlantVillage-Dataset-master/raw/color"
classes = os.listdir(dataset_path)
print("number of classes: ", len(classes))
for c in classes[:38]:
    print(c)
# Out:
# number of classes:  38
# Apple___Apple_scab
# Apple___Black_rot
# Apple___Cedar_apple_rust
# Apple___healthy
# Blueberry___healthy
# Cherry_(including_sour)___healthy
# Cherry_(including_sour)___Powdery_mildew
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
# Corn_(maize)___Common_rust_
# Corn_(maize)___healthy
# Corn_(maize)___Northern_Leaf_Blight
# Grape___Black_rot
# Grape___Esca_(Black_Measles)
# Grape___healthy
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# Orange___Haunglongbing_(Citrus_greening)
# Peach___Bacterial_spot
# Peach___healthy
# Pepper,_bell___Bacterial_spot
# Pepper,_bell___healthy
# Potato___Early_blight
# Potato___healthy
# Potato___Late_blight
# Raspberry___healthy
# Soybean___healthy
# Squash___Powdery_mildew
# Strawberry___healthy
# Strawberry___Leaf_scorch
# Tomato___Bacterial_spot
# Tomato___Early_blight
# Tomato___healthy
# Tomato___Late_blight
# Tomato___Leaf_Mold
# Tomato___Septoria_leaf_spot
# Tomato___Spider_mites Two-spotted_spider_mite
# ...

# %%
for i in classes :
    class_path = os.path.join(dataset_path, i)

    if os.path.isdir(class_path):

        image_count = len(os.listdir(class_path))
      
        print(f"Class: {i}, Number of images: {image_count}")
# Out:
# Class: Apple___Apple_scab, Number of images: 630
# Class: Apple___Black_rot, Number of images: 621
# Class: Apple___Cedar_apple_rust, Number of images: 275
# Class: Apple___healthy, Number of images: 1645
# Class: Blueberry___healthy, Number of images: 1502
# Class: Cherry_(including_sour)___healthy, Number of images: 854
# Class: Cherry_(including_sour)___Powdery_mildew, Number of images: 1052
# Class: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, Number of images: 513
# Class: Corn_(maize)___Common_rust_, Number of images: 1192
# Class: Corn_(maize)___healthy, Number of images: 1162
# Class: Corn_(maize)___Northern_Leaf_Blight, Number of images: 985
# Class: Grape___Black_rot, Number of images: 1180
# Class: Grape___Esca_(Black_Measles), Number of images: 1383
# Class: Grape___healthy, Number of images: 423
# Class: Grape___Leaf_blight_(Isariopsis_Leaf_Spot), Number of images: 1076
# Class: Orange___Haunglongbing_(Citrus_greening), Number of images: 5507
# ...

# %%
dataset_path = r"D:\FruitDiseaseDissertation\Dataset\PlantDoc-Dataset-master"
directory = os.listdir(dataset_path)
for i in directory:
    full_path = os.path.join(dataset_path, i)
    if os.path.isdir(full_path):
        print(f"{i} is a directory.")
    else:
        print(f"{i} is a file.")
# Out:
# LICENSE.txt is a file.
# PlantDoc_Examples.png is a file.
# README.md is a file.
# test is a directory.
# train is a directory.

# %%
dataset_path = r"D:\FruitDiseaseDissertation\Dataset\PlantDoc-Dataset-master\train"
directory = os.listdir(dataset_path)
for i in directory:
    full_path = os.path.join(dataset_path,i)

    if os.path.isdir(full_path):

        image_count = len(os.listdir(full_path))

        print(f"Class: {i}, Number of images: {image_count}")
# Out:
# Class: Apple leaf, Number of images: 82
# Class: Apple rust leaf, Number of images: 78
# Class: Apple Scab Leaf, Number of images: 83
# Class: Bell_pepper leaf, Number of images: 53
# Class: Bell_pepper leaf spot, Number of images: 62
# Class: Blueberry leaf, Number of images: 104
# Class: Cherry leaf, Number of images: 47
# Class: Corn Gray leaf spot, Number of images: 64
# Class: Corn leaf blight, Number of images: 179
# Class: Corn rust leaf, Number of images: 106
# Class: grape leaf, Number of images: 57
# Class: grape leaf black rot, Number of images: 56
# Class: Peach leaf, Number of images: 102
# Class: Potato leaf early blight, Number of images: 108
# Class: Potato leaf late blight, Number of images: 97
# Class: Raspberry leaf, Number of images: 112
# Class: Soyabean leaf, Number of images: 57
# Class: Squash Powdery mildew leaf, Number of images: 124
# Class: Strawberry leaf, Number of images: 88
# Class: Tomato Early blight leaf, Number of images: 79
# ...

# %%
#standadsing folder name for the comparision
import os
pltvillage_classes = sorted(os.listdir(r"../Dataset/PlantVillage-Dataset-master/raw/color"))
pltdoc_classes = sorted(os.listdir(r"D:\FruitDiseaseDissertation\Dataset\PlantDoc-Dataset-master\train"))
print("PlantVillage classes: ", pltvillage_classes)
print("PlantDoc classes: ", pltdoc_classes)
# Out:
# PlantVillage classes:  ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Blueberry___healthy', 'Cherry_(including_sour)___Powdery_mildew', 'Cherry_(including_sour)___healthy', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Corn_(maize)___Common_rust_', 'Corn_(maize)___Northern_Leaf_Blight', 'Corn_(maize)___healthy', 'Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Grape___healthy', 'Orange___Haunglongbing_(Citrus_greening)', 'Peach___Bacterial_spot', 'Peach___healthy', 'Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy', 'Raspberry___healthy', 'Soybean___healthy', 'Squash___Powdery_mildew', 'Strawberry___Leaf_scorch', 'Strawberry___healthy', 'Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_m
# ...

# %%
import pandas as pd
mapping_path =r"D:\FruitDiseaseDissertation\report\paper_mapping.xlsx"
mapping_df = pd.read_excel(mapping_path)
mapping_df.head()
# Out:
#              Plant village         Plant doc Standardized label   Status
# 0        Apple___Apple_scab  Apple Scab Leaf         apple_scab    MATCH
# 1         Apple___Black_rot              NaN                TBD  PV_ONLY
# 2  Apple___Cedar_apple_rust  Apple rust leaf         apple_rust    MATCH
# 3           Apple___healthy       Apple leaf      apple_healthy    MATCH
# 4                       NaN              NaN                NaN      NaN

# %%
print(mapping_df.columns)
# Out:
# Index(['Plant village ', 'Plant doc', 'Standardized label', 'Status'], dtype='str')

# %%
mapping_df['Status'].value_counts()
# Out:
# Status
# MATCH        22
# PV_ONLY      13
# AMBIGUOUS     5
# Name: count, dtype: int64

# %%
import os
pv_classes = sorted(os.listdir(r"D:\FruitDiseaseDissertation\Dataset\PlantVillage-Dataset-master\raw\color"))

pv_sheet_classes = mapping_df['Plant village '].dropna()

missing_pv = [
    cls for cls in pv_sheet_classes
    if cls not in pv_classes
]

print("plant village name not found :")
print(missing_pv)
# Out:
# plant village name not found :
# []

# %%
pd_classes = sorted(os.listdir(r"D:\FruitDiseaseDissertation\Dataset\PlantDoc-Dataset-master\train"))
pd_sheet_classes = mapping_df['Plant doc'].dropna()
missing_pd = []
for cls in pd_sheet_classes:
    if cls not in pd_classes:
        missing_pd.append(cls)
print("plant doc name not found :")
print(missing_pd)
# Out:
# plant doc name not found :
# []

# %%
matched_df = mapping_df[mapping_df['Status'] == 'MATCH']
matched_df
# Out:
#                                        Plant village   \
# 0                                  Apple___Apple_scab
# 2                            Apple___Cedar_apple_rust
# 3                                     Apple___healthy
# 5                       Pepper,_bell___Bacterial_spot
# 6                              Pepper,_bell___healthy
# 11  Corn_(maize)___Cercospora_leaf_spot Gray_leaf_...
# 12                        Corn_(maize)___Common_rust_
# 13                Corn_(maize)___Northern_Leaf_Blight
# 16                                  Grape___Black_rot
# 19                                    Grape___healthy
# 22                                    Peach___healthy
# 24                              Potato___Early_blight
# 25                               Potato___Late_blight
# 38                            Squash___Powdery_mildew
# 40                            Tomato___Bacterial_spot
# 41                              Tomato___Early_blight
# ...

# %%
ambiguous_df = mapping_df[mapping_df["Status"] == "AMBIGUOUS"]
ambiguous_df
# Out:
#                        Plant village         Plant doc Standardized label  \
# 9   Cherry_(including_sour)___healthy      Cherry leaf                TBD
# 29                                NaN   Raspberry leaf                TBD
# 31                                NaN    Soyabean leaf                TBD
# 36                                NaN  Strawberry leaf                TDB
# 50                                NaN      Tomato leaf                TBD
#
#        Status
# 9   AMBIGUOUS
# 29  AMBIGUOUS
# 31  AMBIGUOUS
# 36  AMBIGUOUS
# 50  AMBIGUOUS

# %%
dataset_specific_df = mapping_df[
    mapping_df["Status"].isin(["PV_ONLY", "PD_ONLY"])
 ]

dataset_specific_df
# Out:
#                                 Plant village  Plant doc  \
# 1                            Apple___Black_rot       NaN
# 8     Cherry_(including_sour)___Powdery_mildew       NaN
# 14                      Corn_(maize)___healthy       NaN
# 17                Grape___Esca_(Black_Measles)       NaN
# 18  Grape___Leaf_blight_(Isariopsis_Leaf_Spot)       NaN
# 21                      Peach___Bacterial_spot       NaN
# 26                            Potato___healthy       NaN
# 28                         Raspberry___healthy       NaN
# 30                           Soybean___healthy       NaN
# 34                    Strawberry___Leaf_scorch       NaN
# 35                        Strawberry___healthy       NaN
# 46                        Tomato___Target_Spot       NaN
# 49                            Tomato___healthy       NaN
#
#         Standardized label   Status
# 1                      TBD  PV_ONLY
# 8    cherry_powdery_mildew  PV_ONLY
# 14            corn_healthy  PV_ONLY
# ...
