# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras

IMG_SIZE = 224
BATCH_SIZE = 16

PLANTDOC_PATH = r"D:\FruitDiseaseDissertation\Dataset\PlantDoc-Dataset-master"

pd_test = pd.read_csv(
    "../processed_data/plantdoc_test.csv"
)

print("PlantDoc test images:", len(pd_test))
print("PlantDoc test classes:", pd_test["class_name"].nunique())

print("\nPlantDoc classes:")
for cls in sorted(pd_test["class_name"].unique()):
    print(cls)
